# %%
import custom_lib as c

# %%
url = 'https://www.stockbiz.vn/Stocks/VHM/HistoricalQuotes.aspx'

# prmt = { 'startDate' : start_date, 'endDate' : end_date, 'symbol' : symbol, 'duration' : 'd' } 
payload = {'Cart_ctl00_webPartManager_wp1770166562_wp1427611561_callbackData_Callback_Param' : c.datetime(2022,1,1) ,
        'Cart_ctl00_webPartManager_wp1770166562_wp1427611561_callbackData_Callback_Param' : c.datetime(2022,1,31) ,
        'Cart_ctl00_webPartManager_wp1770166562_wp1427611561_callbackData_Callback_Param' : 1
        }
response = c.requests.post(url, params = payload)
print(response.text)
# df = c.pd.read_html(response.text)

# df 
# df1 = c.pd.DataFrame(df)
# df
# Out:
# <CallbackError><![CDATA[String was not recognized as a valid DateTime.]]></CallbackError>

# %% [markdown]
# ![image.png](attachment:image.png)
